# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijaysrini161/Vijayasini/blob/main/image_conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Image Filter App for Google Colab
from google.colab import files
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt
import numpy as np
import io


# Upload image
print("📤 Upload an image:")
uploaded = files.upload()


# Load the image
image_name = list(uploaded.keys())[0]
image = Image.open(image_name)


# Display original image
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(image)
plt.axis("off")


# Apply filters
def apply_filter(image, filter_type):
    if filter_type == "grayscale":
        return image.convert("L")
    elif filter_type == "sepia":
        img = np.array(image)
        tr = [0.393, 0.769, 0.189]
        tg = [0.349, 0.686, 0.168]
        tb = [0.272, 0.534, 0.131]


        sepia = np.dot(img[..., :3], [tr, tg, tb])
        sepia = np.clip(sepia, 0, 255)
        sepia = sepia.astype("uint8")


        return Image.fromarray(sepia)
    elif filter_type == "blur":
        return image.filter(ImageFilter.BLUR)
    elif filter_type == "edge":
        return image.filter(ImageFilter.FIND_EDGES)
    else:
        return image


# Choose filter
print("\nChoose a filter:")
print("1. Grayscale")
print("2. Sepia")
print("3. Blur")
print("4. Edge Detection")


choice = input("Enter filter number (1-4): ")


filters = {
    "1": "grayscale",
    "2": "sepia",
    "3": "blur",
    "4": "edge"
}


if choice in filters:
    filtered_image = apply_filter(image, filters[choice])


    # Display filtered image
    plt.subplot(1, 2, 2)
    plt.title(f"{filters[choice].capitalize()} Filter")
    plt.imshow(filtered_image)
    plt.axis("off")
    plt.show()


    # Save and download filtered image
    output_name = f"filtered_{filters[choice]}.png"
    filtered_image.save(output_name)
    files.download(output_name)


    print(f"✅ Filter applied! Downloading '{output_name}'...")


else:
    print("❌ Invalid choice. Try again!")
# Out:
# 📤 Upload an image:
#      <input type="file" id="files-1d4fe1ba-5a03-4e04-bb23-de7ab07303ab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1d4fe1ba-5a03-4e04-bb23-de7ab07303ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
